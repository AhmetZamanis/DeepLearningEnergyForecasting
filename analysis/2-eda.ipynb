# %% [markdown]
# This notebook performs some exploratory analysis on the merged energy consumption, generation & pricing dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.eda.time_plot import time_plot
from src.eda.seasonal_plots import seasonal_plot1, seasonal_plot2, seasonal_plot3
from src.eda.autocorrelation import plot_autocorrelation

# %%
# Plot settings
plt.rcParams["figure.autolayout"] = True
plt.rcParams['figure.dpi'] = 100
sns.set_style("darkgrid")

# %%
data_dir = "../data/processed/"

# %% [markdown]
# ## Data prep

# %%
# Load data, convert "time" to datetime format, add deficit column
df = pd.read_csv(data_dir + "full_data.csv")
df["time"] = pd.to_datetime(df["time"], format = "%d:%m:%Y:%H:%M")
df["deficit"] = df["consumption_MWh"] - df["total_generation_MWh"]

# %%
df
# Out:
#                      time  consumption_MWh  total_generation_MWh  natural_gas  \
# 0     2018-01-01 00:00:00         27412.81              27412.81      6926.78
# 1     2018-01-01 01:00:00         26324.39              26324.39      6603.44
# 2     2018-01-01 02:00:00         24635.32              24635.32      6040.77
# 3     2018-01-01 03:00:00         23872.12              23872.12      5938.46
# 4     2018-01-01 04:00:00         23194.89              23194.89      5665.41
# ...                   ...              ...                   ...          ...
# 52579 2023-12-31 19:00:00         35090.93              34753.40      5567.82
# 52580 2023-12-31 20:00:00         33310.94              31441.31      4792.96
# 52581 2023-12-31 21:00:00         32083.96              30368.98      4000.94
# 52582 2023-12-31 22:00:00         30469.49              30386.41      2903.52
# 52583 2023-12-31 23:00:00         30029.91              28835.50      2767.37
#
#        hydro_dam  lignite  hydro_river  coal_imported     wind  solar  ...  \
# 0        4820.40  5226.32      1900.32        5314.05  1179.51    0.0  ...
# 1        3644.32  5277.19      1877.83        5715.61  1148.46    0.0  ...
# 2        2711.00  5325.47      1708.49        5701.37  1216.38    0.0  ...
# 3        2524.37  5265.91      1662.59        5205.43  1298.11    0.0  ...
# 4        2462.71  5282.88      1697.96        4804.19  1220.91    0.0  ...
# ...          ...      ...          ...            ...      ...    ...  ...
# 52579    8719.86  5311.18      2287.36        9100.92   359.70    0.0  ...
# 52580    7881.64  4908.48      2083.33        7613.93   459.87    0.0  ...
# 52581    7513.96  4911.94      1966.32        7656.56   552.62    0.0  ...
# 52582    8119.63  4615.93      1837.75        8390.47   720.11    0.0  ...
# 52583    8118.94  5144.29      1646.53        7094.63   890.48    0.0  ...
#
#        hard_coal  biomass  naphtha  LNG  international  waste_heat  TRY/MWh  \
# 0         189.50   210.96      0.0  0.0         297.00       92.08   207.60
# 1         205.50   211.67      0.0  0.0         287.00       91.14   205.34
# 2         201.50   209.89      0.0  0.0         169.00       91.06   164.94
# 3         211.50   211.24      0.0  0.0         214.00       91.83   154.52
# 4         307.50   214.31      0.0  0.0         203.00       91.23   112.64
# ...          ...      ...      ...  ...            ...         ...      ...
# 52579     613.05   997.70      0.0  0.0         270.20       82.49  2499.67
# 52580     612.95   983.26      0.0  0.0         539.84       85.01  2472.34
# 52581     607.59   977.02      0.0  0.0         629.91       84.63  2472.33
# 52582     608.31   987.47      0.0  0.0         627.77       83.35  1800.00
# 52583     624.68   993.54      0.0  0.0           0.00       80.41  1345.15
#
#        USD/MWh  EUR/MWh  deficit
# 0        55.04    45.97     0.00
# 1        54.44    45.47     0.00
# 2        43.73    36.53     0.00
# 3        40.97    34.22     0.00
# 4        29.86    24.95     0.00
# ...        ...      ...      ...
# 52579    84.91    76.74   337.53
# 52580    83.98    75.90  1869.63
# 52581    83.98    75.90  1714.98
# 52582    61.15    55.26    83.08
# 52583    45.69    41.30  1194.41
#
# [52584 rows x 23 columns]

# %%
# Aggregate by day
df_daily = df.copy().set_index("time")
agg_funcs = ("sum " * 18).split(" ")[0:-1]
agg_funcs = agg_funcs + ["mean", "mean", "mean", "sum"]
agg_cols = dict(zip(df_daily.columns.values, agg_funcs))
df_daily = df_daily.groupby(df_daily.index.date).aggregate(agg_cols).reset_index(names = "time")

# %%
df_daily
# Out:
#             time  consumption_MWh  total_generation_MWh  natural_gas  \
# 0     2018-01-01        672127.68             672127.68    205081.00
# 1     2018-01-02        811275.64             811275.64    308838.32
# 2     2018-01-03        851617.52             851617.52    333147.20
# 3     2018-01-04        863492.42             863492.42    322638.10
# 4     2018-01-05        854542.70             854542.70    305823.09
# ...          ...              ...                   ...          ...
# 2186  2023-12-27        909315.54             856208.37    142398.25
# 2187  2023-12-28        905605.21             853261.07    135465.07
# 2188  2023-12-29        892609.49             832640.42    130462.50
# 2189  2023-12-30        834855.23             781688.92     90015.98
# 2190  2023-12-31        741161.27             689296.39     70555.59
#
#       hydro_dam    lignite  hydro_river  coal_imported      wind    solar  \
# 0      83771.12  121224.96     46900.08      134299.83  31365.10    23.36
# 1      79695.24  119643.01     43806.76      152959.50  61325.11    61.47
# 2      82439.29  118305.31     44896.98      173464.16  56128.55    51.77
# 3      93175.93  122406.92     51436.68      185086.43  46931.16    26.75
# 4      83901.90  128787.71     54348.47      179947.70  60845.47    36.69
# ...         ...        ...          ...            ...       ...      ...
# 2186  190742.68  115704.89     52189.57      183787.70  68434.22  9165.28
# 2187  192632.99  127101.97     49956.02      197843.77  46635.31  8861.83
# 2188  183107.01  127252.58     47398.82      194948.13  42067.22  7883.39
# 2189  173765.66  120931.96     45002.51      196260.36  49183.75  9110.93
# 2190  155053.55  127946.82     43039.96      186167.88  12863.81  8024.24
#
#       ...  hard_coal   biomass  naphtha    LNG  international  waste_heat  \
# 0     ...    7961.50   5228.04      0.0  24.17        5311.40     2144.96
# 1     ...    8503.00   5749.52      0.0  20.19       -1522.00     2063.01
# 2     ...    8436.50   5768.05      0.0   0.00       -2908.01     2125.97
# 3     ...    8073.00   5576.65      0.0  22.49       -4210.55     2205.46
# 4     ...    7974.00   5950.88      0.0  24.07       -5261.21     2170.48
# ...   ...        ...       ...      ...    ...            ...         ...
# 2186  ...   14266.03  23940.91      0.0   0.00       15985.42     1786.96
# 2187  ...   14386.98  23979.82      0.0   0.00       16837.98     1946.87
# 2188  ...   14749.89  24333.89      0.0   0.00       20388.08     1996.91
# 2189  ...   14664.43  24033.67      0.0   0.00       19247.38     2137.30
# 2190  ...   14565.94  23769.43      0.0   0.00        9928.49     1996.93
#
#           TRY/MWh    USD/MWh    EUR/MWh   deficit
# 0      161.041667  42.695417  35.664583      0.00
# 1      175.875833  46.627917  38.949167      0.00
# 2      173.490833  46.076667  38.235833      0.00
# 3      175.292917  46.599583  38.723333      0.00
# 4      169.443333  45.065833  37.431250      0.00
# ...           ...        ...        ...       ...
# 2186  2114.216667  72.378750  65.706250  53107.17
# 2187  2123.542083  72.562917  65.861250  52344.14
# 2188  2201.463750  75.037917  67.908333  59969.07
# 2189  2003.797500  68.162917  61.288750  53166.31
# 2190  1953.047500  66.344167  59.958750  51864.88
#
# [2191 rows x 23 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Time plots

# %%
# Consumption
time_plot(df, df_daily, variable = "consumption_MWh")

# %%
# Generation, total
time_plot(df, df_daily, variable = "total_generation_MWh")

# %% [markdown]
# Consumption & generation shows a slight positive linear trend. Probably more steep as the historical data extends backwards.

# %%
# Deficit
time_plot(df, df_daily, variable = "deficit")

# %% [markdown]
# Deficits are mostly zero with occasional spikes before 2021, while they are large & consistent afterwards. Probably a change in data collection.

# %%
# Market clearing price, TRY
time_plot(df, df_daily, variable = "TRY/MWh")

# %%
# Market clearing price, USD
time_plot(df, df_daily, variable = "USD/MWh")

# %%
# Market clearing price, EUR
time_plot(df, df_daily, variable = "EUR/MWh")

# %% [markdown]
# Prices ramped up exponentially after 2021, and declined exponentially from roughly fall 2022, possibly returning to a new process mean around roughly mid 2023. Likely no linear trend otherwise.

# %% [markdown]
# ## Seasonal plots

# %% [markdown]
# ### Consumption

# %%
# Consumption seasonality, by year
seasonal_plot1(
    df,
    variable = "consumption_MWh",
    groupby_year = True
)

# %%
# Consumption seasonality, by month
seasonal_plot2(
    df,
    variable = "consumption_MWh",
    groupby_month = True
)

# %%
# Consumption day of month seasonality, by month
seasonal_plot3(df, variable = "consumption_MWh")

# %% [markdown]
# ### Deficit

# %%
# Deficit seasonality, by year
seasonal_plot1(
    df,
    variable = "deficit",
    groupby_year = True
)

# %%
# Deficit seasonality, by month
seasonal_plot2(
    df,
    variable = "deficit",
    groupby_month = True
)

# %% [markdown]
# Deficits very dependably ramp from 6am to 12 am, decline to 18pm. Sometimes they happen around 12am. They ramp towards the summer and decline afterwards.

# %% [markdown]
# ### Price USD

# %%
# Price seasonality, by year
seasonal_plot1(
    df,
    variable = "USD/MWh",
    groupby_year = True
)

# %%
# Price seasonality, by month
seasonal_plot2(
    df,
    variable = "USD/MWh",
    groupby_month = True
)

# %%
# Price day of month seasonality, by month
seasonal_plot3(df, variable = "USD/MWh")

# %% [markdown]
# Seasonality features to use: Day of hour, day of week. Possibly month, but hard to tell.

# %% [markdown]
# ## Autocorrelation plots

# %%
# Price
plot_autocorrelation(df, df_daily)

# %%
# Consumption
plot_autocorrelation(df, df_daily, variable = "consumption_MWh")

# %%
# Deficit
plot_autocorrelation(df, df_daily, variable = "deficit")
