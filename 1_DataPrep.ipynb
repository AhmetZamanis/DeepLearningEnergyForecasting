# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# %%
input_dir = "./InputData/"
output_dir = "./OutputData/"

# %% [markdown]
# ## Data prep, consumption data

# %%
# Load consumption data
df_consumption = pd.read_csv(input_dir + "Real_Time_Consumption.csv", sep = ";")
df_consumption = df_consumption.rename({
    "Tarih": "date",
    "Saat": "hour",
    "Tüketim Miktarı(MWh)": "consumption_MWh"
}, axis = 1)

# %%
# Combine date & hour
df_consumption["time"] = df_consumption["date"].str.replace(".", ":") + ":" + df_consumption["hour"]
df_consumption = df_consumption.drop(["date", "hour"], axis = 1)

# %%
# Remove dots indicating thousands
df_consumption["consumption_MWh"] = df_consumption["consumption_MWh"].str.replace(".", "")

# Change fractional commas to dots, change consumption to float
df_consumption["consumption_MWh"] = df_consumption["consumption_MWh"].str.replace(",", ".").astype(float)

# %%
df_consumption
# Out:
#        consumption_MWh              time
# 0             29489.46  01:01:2021:00:00
# 1             28067.11  01:01:2021:01:00
# 2             26527.08  01:01:2021:02:00
# 3             25327.19  01:01:2021:03:00
# 4             24719.72  01:01:2021:04:00
# ...                ...               ...
# 26275         35090.93  31:12:2023:19:00
# 26276         33310.94  31:12:2023:20:00
# 26277         32083.96  31:12:2023:21:00
# 26278         30469.49  31:12:2023:22:00
# 26279         30029.91  31:12:2023:23:00
#
# [26280 rows x 2 columns]

# %%
# Check missing values
pd.isna(df_consumption).sum()
# Out:
# consumption_MWh    0
# time               0
# dtype: int64

# %%
# Check unusual values
df_consumption.describe()
# Out:
#        consumption_MWh
# count     26280.000000
# mean      37097.680535
# std        5723.335252
# min       19209.200000
# 25%       32357.382500
# 50%       37370.550000
# 75%       40944.010000
# max       55575.020000

# %% [markdown]
# ## Data prep, generation data

# %%
# Load 2021 data
df_generation = pd.read_csv(input_dir + "Real_Time_Generation21.csv", sep = ";")

# Load & concatenate 2022 & 2023 data
for year in [22, 23]:
    df = pd.read_csv(input_dir + f"Real_Time_Generation{year}.csv", sep = ";")
    df_generation = pd.concat([df_generation, df])

# %%
newnames = [
    "date", "hour", "total_generation_MWh", "natural_gas", "hydro_dam", "lignite", 
    "hydro_river", "coal_imported", "wind", "solar", "fuel_oil", "geothermal", 
    "asphaltite_coal", "hard_coal", "biomass", "naphtha", "LNG", "international", 
    "waste_heat"]

# %%
# Reindex, rename columns
df_generation = df_generation.reset_index(drop = True)
df_generation = df_generation.rename(
    dict(zip(df_generation.columns, newnames)), axis = 1)

# %%
# Combine date & hour
df_generation["time"] = df_generation["date"].str.replace(".", ":") + ":" + df_generation["hour"]
df_generation = df_generation.drop(["date", "hour"], axis = 1)

# %%
# Change fractional commas to dots
df_generation = df_generation.apply(
    lambda col: col.astype(str), axis = 1)

df_generation.iloc[:, :-1] = df_generation.iloc[:, :-1].apply(
    lambda col: col.str.replace(",", "."), 
    axis = 1)

# Change datatypes
newtypes = ("float " * 17).split(" ")[0:-1]
newtypes.append("object")
df_generation = df_generation.astype(
    dict(zip(df_generation.columns, newtypes)))

# %%
df_generation
# Out:
#        total_generation_MWh  natural_gas  hydro_dam  lignite  hydro_river  \
# 0                  29488.11      7083.97    1551.39  5256.89       686.07
# 1                  28065.76      6072.81    1387.63  5121.95       703.90
# 2                  26527.08      4878.19    1507.96  5110.55       667.26
# 3                  25327.19      4394.61    1652.86  5029.12       651.91
# 4                  24719.72      4191.38    1615.38  5012.93       670.94
# ...                     ...          ...        ...      ...          ...
# 26275              34753.40      5567.82    8719.86  5311.18      2287.36
# 26276              31441.31      4792.96    7881.64  4908.48      2083.33
# 26277              30368.98      4000.94    7513.96  4911.94      1966.32
# 26278              30386.41      2903.52    8119.63  4615.93      1837.75
# 26279              28835.50      2767.37    8118.94  5144.29      1646.53
#
#        coal_imported     wind  solar  fuel_oil  geothermal  asphaltite_coal  \
# 0            7673.92  4836.19    0.0     33.20     1238.01           218.59
# 1            7530.56  4826.45    0.0     34.00     1244.05           223.00
# 2            6979.91  4750.11    0.0     30.30     1246.75           223.00
# 3            6536.85  4432.18    0.0     30.80     1248.66           220.79
# 4            6266.92  4321.98    0.0     31.40     1246.97           220.80
# ...              ...      ...    ...       ...         ...              ...
# 26275        9100.92   359.70    0.0     93.36     1219.49           130.27
# 26276        7613.93   459.87    0.0     93.46     1254.10           132.48
# 26277        7656.56   552.62    0.0     88.76     1246.25           132.48
# 26278        8390.47   720.11    0.0     83.06     1278.77           130.27
# 26279        7094.63   890.48    0.0     84.37     1257.78           132.48
#
#        hard_coal  biomass  naphtha  LNG  international  waste_heat  \
# 0         603.87   577.37      0.0  0.0        -364.20       92.84
# 1         599.09   575.69      0.0  0.0        -346.00       92.63
# 2         603.49   581.60      0.0  0.0        -142.00       89.96
# 3         603.81   579.64      0.0  0.0        -145.00       90.96
# 4         602.66   583.37      0.0  0.0        -137.00       91.99
# ...          ...      ...      ...  ...            ...         ...
# 26275     613.05   997.70      0.0  0.0         270.20       82.49
# 26276     612.95   983.26      0.0  0.0         539.84       85.01
# 26277     607.59   977.02      0.0  0.0         629.91       84.63
# 26278     608.31   987.47      0.0  0.0         627.77       83.35
# 26279     624.68   993.54      0.0  0.0           0.00       80.41
#
#                    time
# 0      01:01:2021:00:00
# 1      01:01:2021:01:00
# 2      01:01:2021:02:00
# 3      01:01:2021:03:00
# 4      01:01:2021:04:00
# ...                 ...
# 26275  31:12:2023:19:00
# 26276  31:12:2023:20:00
# 26277  31:12:2023:21:00
# 26278  31:12:2023:22:00
# 26279  31:12:2023:23:00
#
# [26280 rows x 18 columns]

# %%
# Check missing values
pd.isna(df_generation).sum()
# Out:
# total_generation_MWh    0
# natural_gas             0
# hydro_dam               0
# lignite                 0
# hydro_river             0
# coal_imported           0
# wind                    0
# solar                   0
# fuel_oil                0
# geothermal              0
# asphaltite_coal         0
# hard_coal               0
# biomass                 0
# naphtha                 0
# LNG                     0
# international           0
# waste_heat              0
# time                    0
# dtype: int64

# %%
# Check unusual values
df_generation.describe()
# Out:
#        total_generation_MWh   natural_gas     hydro_dam       lignite  \
# count          26280.000000  26280.000000  26280.000000  26280.000000
# mean           35600.650430   9352.388915   4999.710506   4886.494534
# std             5229.624571   4231.276353   2537.886447    540.210669
# min            16184.090000    663.710000    296.690000   2366.310000
# 25%            31627.865000   6079.682500   3055.447500   4563.942500
# 50%            35626.295000   9502.185000   4726.520000   4908.335000
# 75%            39280.475000  12470.372500   6705.992500   5254.427500
# max            51285.690000  19453.650000  15784.770000   6680.400000
#
#         hydro_river  coal_imported          wind         solar      fuel_oil  \
# count  26280.000000   26280.000000  26280.000000  26280.000000  26280.000000
# mean    2069.004806    7223.775079   3776.070075    310.683250     65.907522
# std     1304.657072    2021.322339   2077.161811    435.431178     24.371020
# min      389.390000     956.350000    158.890000     -0.300000      0.000000
# 25%     1088.125000    5625.672500   2023.902500      0.000000     40.700000
# 50%     1533.370000    7701.160000   3482.625000     19.350000     71.900000
# 75%     2866.257500    8741.907500   5341.752500    549.755000     89.002500
# max     6103.590000   11352.140000   9737.590000   1547.410000    105.800000
#
#          geothermal  asphaltite_coal     hard_coal       biomass  naphtha  \
# count  26280.000000     26280.000000  26280.000000  26280.000000  26280.0
# mean    1159.420432       210.401713    461.234166    818.720919      0.0
# std      119.470188        82.229953     76.131472    120.001982      0.0
# min      775.850000         0.000000    138.200000    492.470000      0.0
# 25%     1076.895000       178.840000    409.290000    719.597500      0.0
# 50%     1183.940000       205.340000    462.965000    852.790000      0.0
# 75%     1258.240000       245.080000    525.180000    916.695000      0.0
# max     1458.280000       368.720000    656.490000   1039.900000      0.0
#
#            LNG  international    waste_heat
# count  26280.0   26280.000000  26280.000000
# mean       0.0     181.344213     85.487258
# std        0.0     392.650681     13.818308
# min        0.0   -1417.690000     30.780000
# 25%        0.0    -137.600000     76.237500
# 50%        0.0     153.400000     85.710000
# 75%        0.0     466.450000     95.380000
# max        0.0    1648.540000    127.760000

# %%
# Check if the total adds up
(df_generation["total_generation_MWh"] - df_generation.iloc[:, 1:-1].sum(axis = 1)).describe()
# Out:
# count    2.628000e+04
# mean     7.041096e-03
# std      3.086210e-01
# min     -2.182787e-11
# 25%     -3.637979e-12
# 50%      0.000000e+00
# 75%      3.637979e-12
# max      2.317000e+01
# dtype: float64

# %% [markdown]
# ## Data prep, market clearing price data

# %%
# Load price data
df_price = pd.read_csv(input_dir + "Market_Clearing_Price.csv", sep = ";")
df_price = df_price.rename({
    "Tarih": "date",
    "Saat": "hour",
    "PTF (TL/MWh)": "TRY/MWh",
    "PTF (USD/MWh)": "USD/MWh",
    "PTF (EUR/MWh)": "EUR/MWh"
}, axis = 1)

# %%
# Combine date & hour
df_price["time"] = df_price["date"].str.replace(".", ":") + ":" + df_price["hour"]
df_price = df_price.drop(["date", "hour"], axis = 1)

# %%
# Remove dots indicating thousands
df_price.iloc[:, :-1] = df_price.iloc[:, :-1].apply(
    lambda col: col.str.replace(".", ""), 
    axis = 1)

# Change fractional commas to dots, change price to float
df_price.iloc[:, :-1] = df_price.iloc[:, :-1].apply(
    lambda col: col.str.replace(",", "."), 
    axis = 1)

# Change datatypes
newtypes = ("float " * 3).split(" ")[0:-1]
newtypes.append("object")
df_price = df_price.astype(
    dict(zip(df_price.columns, newtypes)))

# %%
df_price
# Out:
#        TRY/MWh  USD/MWh  EUR/MWh              time
# 0       263.99    35.96    29.31  01:01:2021:00:00
# 1       236.99    32.29    26.31  01:01:2021:01:00
# 2       216.70    29.52    24.06  01:01:2021:02:00
# 3       218.07    29.71    24.21  01:01:2021:03:00
# 4       208.99    28.47    23.20  01:01:2021:04:00
# ...        ...      ...      ...               ...
# 26275  2499.67    84.91    76.74  31:12:2023:19:00
# 26276  2472.34    83.98    75.90  31:12:2023:20:00
# 26277  2472.33    83.98    75.90  31:12:2023:21:00
# 26278  1800.00    61.15    55.26  31:12:2023:22:00
# 26279  1345.15    45.69    41.30  31:12:2023:23:00
#
# [26280 rows x 4 columns]

# %%
# Check missing values
pd.isna(df_price).sum()
# Out:
# TRY/MWh    0
# USD/MWh    0
# EUR/MWh    0
# time       0
# dtype: int64

# %%
# Check unusual values
df_price.describe()
# Out:
#             TRY/MWh       USD/MWh       EUR/MWh
# count  26280.000000  26280.000000  26280.000000
# mean    1736.042084     99.886860     92.764924
# std     1198.788668     57.198574     57.510338
# min        0.000000      0.000000      0.000000
# 25%      617.000000     55.307500     48.790000
# 50%     1699.005000     84.890000     78.030000
# 75%     2499.990000    131.357500    121.950000
# max     4800.000000    264.170000    271.630000

# %% [markdown]
# ## Merge & export

# %%
# Merge dataframes, change column order
df = df_consumption.merge(df_generation, on = "time", how = "inner").merge(df_price, on = "time", how = "inner")
cols = np.delete(df.columns.values, 1).tolist()
cols.insert(0, "time")
df = df[cols]

# %%
df
# Out:
#                    time  consumption_MWh  total_generation_MWh  natural_gas  \
# 0      01:01:2021:00:00         29489.46              29488.11      7083.97
# 1      01:01:2021:01:00         28067.11              28065.76      6072.81
# 2      01:01:2021:02:00         26527.08              26527.08      4878.19
# 3      01:01:2021:03:00         25327.19              25327.19      4394.61
# 4      01:01:2021:04:00         24719.72              24719.72      4191.38
# ...                 ...              ...                   ...          ...
# 26275  31:12:2023:19:00         35090.93              34753.40      5567.82
# 26276  31:12:2023:20:00         33310.94              31441.31      4792.96
# 26277  31:12:2023:21:00         32083.96              30368.98      4000.94
# 26278  31:12:2023:22:00         30469.49              30386.41      2903.52
# 26279  31:12:2023:23:00         30029.91              28835.50      2767.37
#
#        hydro_dam  lignite  hydro_river  coal_imported     wind  solar  ...  \
# 0        1551.39  5256.89       686.07        7673.92  4836.19    0.0  ...
# 1        1387.63  5121.95       703.90        7530.56  4826.45    0.0  ...
# 2        1507.96  5110.55       667.26        6979.91  4750.11    0.0  ...
# 3        1652.86  5029.12       651.91        6536.85  4432.18    0.0  ...
# 4        1615.38  5012.93       670.94        6266.92  4321.98    0.0  ...
# ...          ...      ...          ...            ...      ...    ...  ...
# 26275    8719.86  5311.18      2287.36        9100.92   359.70    0.0  ...
# 26276    7881.64  4908.48      2083.33        7613.93   459.87    0.0  ...
# 26277    7513.96  4911.94      1966.32        7656.56   552.62    0.0  ...
# 26278    8119.63  4615.93      1837.75        8390.47   720.11    0.0  ...
# 26279    8118.94  5144.29      1646.53        7094.63   890.48    0.0  ...
#
#        asphaltite_coal  hard_coal  biomass  naphtha  LNG  international  \
# 0               218.59     603.87   577.37      0.0  0.0        -364.20
# 1               223.00     599.09   575.69      0.0  0.0        -346.00
# 2               223.00     603.49   581.60      0.0  0.0        -142.00
# 3               220.79     603.81   579.64      0.0  0.0        -145.00
# 4               220.80     602.66   583.37      0.0  0.0        -137.00
# ...                ...        ...      ...      ...  ...            ...
# 26275           130.27     613.05   997.70      0.0  0.0         270.20
# 26276           132.48     612.95   983.26      0.0  0.0         539.84
# 26277           132.48     607.59   977.02      0.0  0.0         629.91
# 26278           130.27     608.31   987.47      0.0  0.0         627.77
# 26279           132.48     624.68   993.54      0.0  0.0           0.00
#
#        waste_heat  TRY/MWh  USD/MWh  EUR/MWh
# 0           92.84   263.99    35.96    29.31
# 1           92.63   236.99    32.29    26.31
# 2           89.96   216.70    29.52    24.06
# 3           90.96   218.07    29.71    24.21
# 4           91.99   208.99    28.47    23.20
# ...           ...      ...      ...      ...
# 26275       82.49  2499.67    84.91    76.74
# 26276       85.01  2472.34    83.98    75.90
# 26277       84.63  2472.33    83.98    75.90
# 26278       83.35  1800.00    61.15    55.26
# 26279       80.41  1345.15    45.69    41.30
#
# [26280 rows x 22 columns]

# %%
# Export full data
df.to_csv(output_dir + "full_data.csv", index = False)
